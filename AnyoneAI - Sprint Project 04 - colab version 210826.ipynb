# %% [markdown]
# # AnyoneAI - Sprint Project 04
# > Multimodal Product Classification
#
# You've been learning a lot about Deep Learning Algorithms, now we you're gonna be asked to put it all together.

# %%
import os, sys
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tf_keras
sys.modules["tensorflow.keras"] = tf_keras
for sub in ["layers", "models", "applications", "preprocessing",
            "preprocessing.image", "utils", "optimizers", "losses", "callbacks"]:
    try:
        sys.modules[f"tensorflow.keras.{sub}"] = __import__(f"tf_keras.{sub}", fromlist=["_"])
    except ImportError:
        pass

IN_COLAB = "google.colab" in sys.modules
print("keras:", tf_keras.__version__, "| IN_COLAB:", IN_COLAB)
# Out:
# keras: 2.20.1 | IN_COLAB: True

# %%
from tensorflow.keras.layers import Input
print(Input.__module__)     # tiene que empezar con tf_keras, no con keras.src
# Out:
# tf_keras.src.engine.input_layer

# %%
import sys

IN_COLAB = "google.colab" in sys.modules
IN_COLAB
# Out:
# True

# %%
import os
from google.colab import drive

# 1. Conectamos tu Drive
drive.mount('/content/drive')

# 2. Definimos la ruta de tu carpeta
NUEVA_CARPETA = '/content/drive/MyDrive/Spring project 3/Assignment' # Cambia 'assignment' si quieres otro nombre

# 3. La creamos automáticamente (si ya existe, no la sobreescribe)
os.makedirs(NUEVA_CARPETA, exist_ok=True)

# 4. Nos posicionamos dentro de ella
# %cd $NUEVA_CARPETA

print("¡Listo! Ya estás dentro de tu carpeta:", NUEVA_CARPETA)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Spring project 3/Assignment
# ¡Listo! Ya estás dentro de tu carpeta: /content/drive/MyDrive/Spring project 3/Assignment

# %%
if IN_COLAB:
    # Put here the full path to the folder having your Sprint project code
    # e.g. "/content/drive/MyDrive/assignment"
    ROOT_DIR = "/content/drive/MyDrive/Spring project 3/Assignment"
    # %cd $ROOT_DIR
# Out:
# /content/drive/MyDrive/Spring project 3/Assignment

# %% [markdown]
# ## Install dependencies (Only for Colab)

# %%
# !python --version
# Out:
# Python 3.13.15

# %%
if IN_COLAB:
    # !pip install -q -r requirements_colab.txt
    # tensorflow-gpu NO se instala: el tensorflow de Colab ya usa GPU.
    import tensorflow as tf
    print("TF:", tf.__version__, "| GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0 | GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1. Introduction
#
# This is a multi-class classification task: we aim to predict the correct category of a product from BestBuy.com based on its textual and image data. The raw dataset consists of detailed product information stored in JSON files. Our goal is to classify products into one of the predefined categories using both textual and visual features.
#
# The dataset contains two raw JSON files that you can use to understand the data:
# - `products.json`: Contains information about the products such as name, description, price, etc.
# - `categories.json`: Contains hierarchical information about the product categories.
#
# In this project, we'll provide you with a preprocessed dataset and a zip file containing the images. Place the images in the `data/images` folder in the same directory as the notebook.
#
# - Use the file `processed_products_with_images.csv` and place it in the `data` folder.
# - [Download](https://drive.google.com/file/d/14s2aDNTEWse86cWyLhvVIKmob6EbQrm_/view?usp=sharing) and unzip the file `images.zip` and place the images in the `data/images` folder.
#
# The task is divided into several steps:
# 1. **Exploratory Data Analysis (EDA)** on the product dataset.
# 2. **Preprocessing** the dataset to prepare it for model training.
# 3. **Generating embeddings** from both product images and textual descriptions.
# 4. **Training and evaluating machine learning models** using these embeddings to predict the product category.
#
# The project will focus on leveraging both text and image data to improve the classification accuracy.

# %%
### IMPORTS ###
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from src.utils import ImageDownloader
from src.vision_embeddings_tf import get_embeddings_df
from src.nlp_models import HuggingFaceEmbeddings
from src.nlp_models import GPT
from src.utils import preprocess_data, train_test_split_and_feature_extraction
import os

from src.classifiers_classic_ml import train_and_evaluate_model as train_classic

from src.classifiers_mlp import MultimodalDataset
from sklearn.preprocessing import LabelEncoder
from src.classifiers_mlp import train_mlp

# %%
# Parche: safe_open dejó de ser iterable y la ruta PT->TF de transformers lo asume.
import transformers.modeling_tf_pytorch_utils as _tfpt

class _IterableArchive:
    """Envuelve safe_open agregando __iter__ sobre keys(). Mantiene get_tensor,
    asi que la carga sigue siendo lazy (no materializa todo el checkpoint)."""
    def __init__(self, archive): self._a = archive
    def __iter__(self):          return iter(self._a.keys())
    def keys(self):              return self._a.keys()
    def get_tensor(self, name):  return self._a.get_tensor(name)

_orig = _tfpt.load_pytorch_state_dict_in_tf2_model

def _patched(tf_model, pt_state_dict, *args, **kwargs):
    if not isinstance(pt_state_dict, dict) and hasattr(pt_state_dict, "get_tensor"):
        pt_state_dict = _IterableArchive(pt_state_dict)
    return _orig(tf_model, pt_state_dict, *args, **kwargs)

_tfpt.load_pytorch_state_dict_in_tf2_model = _patched
print("parche aplicado")
# Out:
# parche aplicado

# %% [markdown]
# ### 1.1 Getting the data
#
# To access the data for this project, you only need the file `processed_products_with_images.csv`, and the images from [this link](https://drive.google.com/file/d/14s2aDNTEWse86cWyLhvVIKmob6EbQrm_/view?usp=sharing). You can place the file in the `data` directory and the images in the `data/images` directory. The images were downloaded using the `ImageDownloader` class provided in the `utils.py` file in a 224 x 224 pixel format, but if you want to download the images yourself in a higher resolution, you can use the `ImageDownloader` class to do so. using the code below:
#
# ```python
# # Load the data:
# CSV_PATH = 'data/processed_products.csv'
# df = pd.read_csv(CSV_PATH)
#
# # Download the images and add the image paths to the dataframe:
# DIR='data/images/'
# SHAPE=(224, 224)
# OVERWRITE=False
# OUTPUT_CSV='data/processed_products_with_images.csv'
#
# # Instantiate the ImageDownloader class
# image_downloader = ImageDownloader(image_dir=DIR, image_size=SHAPE, overwrite=OVERWRITE)
#
# # Download images and get the updated DataFrame
# updated_df = image_downloader.download_images(df)
#
# # Save the updated DataFrame
# updated_df.to_csv(CSV_PATH, index=False)
# ```

# %% [markdown]
# #### 1.1. Simple EDA
#
# - Read the data and display the first few rows.
# - Display some images from the dataset.

# %%
# See the data
df = pd.read_csv('data/processed_products_with_images.csv')
df.head()
# Out:
#       sku                                             name  \
# 0   43900                Duracell - AAA Batteries (4-Pack)
# 1   48530  Duracell - AA 1.5V CopperTop Batteries (4-Pack)
# 2  127687                 Duracell - AA Batteries (8-Pack)
# 3  150115            Energizer - MAX Batteries AA (4-Pack)
# 4  185230                  Duracell - C Batteries (4-Pack)
#
#                                          description  \
# 0  Compatible with select electronic devices; AAA...
# 1  Long-lasting energy; DURALOCK Power Preserve t...
# 2  Compatible with select electronic devices; AA ...
# 3  4-pack AA alkaline batteries; battery tester i...
# 4  Compatible with select electronic devices; C s...
#
#                                                image      type  price  \
# 0  http://img.bbystatic.com/BestBuy_US/images/pro...  HardGood   5.49
# 1  http://img.bbystatic.com/BestBuy_US/images/pro...  HardGood   5.49
# 2  http://img.bbystatic.com/BestBuy_US/images/pro...  HardGood   7.49
# 3  http://img.bbystatic.com/BestBuy_US/images/pro...  HardGood   4.99
# 4  http://img.bbystatic.com/BestBuy_US/images/pro...  HardGood   8.99
#
#    shipping manufacturer            class_id       sub_class1_id  num_classes  \
# 0      5.49     Duracell  pcmcat312300050015  pcmcat248700050021            2
# 1      5.49     Duracell  pcmcat312300050015  pcmcat248700050021            2
# 2      5.49     Duracell  pcmcat312300050015  pcmcat248700050021            2
# 3      5.49    Energizer  pcmcat312300050015  pcmcat248700050021            2
# 4      5.49     Duracell  pcmcat312300050015  pcmcat248700050021            2
#
#                image_path
# 0   data/images/43900.jpg
# 1   data/images/48530.jpg
# 2  data/images/127687.jpg
# 3  data/images/150115.jpg
# 4  data/images/185230.jpg

# %%
import os

disponibles = set(os.listdir("data/images"))

df_img = df[df['image_path'].notna()].copy()
df_img = df_img[df_img['image_path'].map(lambda p: os.path.basename(p) in disponibles)]
print(f"usables: {len(df_img)} de {df['image_path'].notna().sum()}")

fig, ax = plt.subplots(2, 3, figsize=(15, 10))
for i in range(2):
    for j in range(3):
        idx = df_img.sample().index[0]
        img = mpimg.imread(df_img.loc[idx, 'image_path'])
        ax[i, j].imshow(img)
        ax[i, j].set_title('\n'.join(df_img.loc[idx, 'name'].split()[:3]))
        ax[i, j].axis('off')

# %% [markdown]
# ## 2.Embedding Generation
#
# We have two types of data: textual and image data. Unfortunately, these data types are high dimensional and extremely different from each other. To make them compatible for a machine learning model, and homogeneous, we will generate embeddings for both the textual and image data.
#
# As you remember from the lectures on embeddings, they are a way to represent high-dimensional data in a lower-dimensional space, some sort of feature extraction. In this project, we will use pre-trained models to generate these embeddings.
#
# The first step is to generate embeddings for both the textual and image data. We will use pre-trained models to generate these embeddings.

# %% [markdown]
# #### 2.1. Image Embeddings
#
# We will use a pre-trained model to generate image embeddings. The model will take an image as input and output a vector of fixed size that represents the image. We will use the `get_embeddings_df` function to extract embeddings from images using a backbone model using `Tensorflow` and `Transformers`.
#
# use `get_embeddings_df` function to extract embeddings from images using a backbone model.
#
# ```python
# get_embeddings_df(
#     batch_size=32,
#     path='data/images',
#     output_dir='Embeddings',
#     backbone='vit_base'
# )
#
# ```
#
# List of possible backbones you can implement:
#
# * resnet50
# * resnet101
# * densenet121
# * densenet169
# * inception_v3
# * convnextv2_tiny
# * convnextv2_base
# * convnextv2_large
# * swin_tiny
# * swin_small
# * swin_base
# * vit_base
# * vit_large
# * clip_base
# * clip_large
#
# **You should at least implement [tensorflow ConvNextV2](https://huggingface.co/docs/transformers/en/model_doc/convnextv2#transformers.TFConvNextV2Model) from Hugging Face and `ResNet50` from [tensorflow.keras.applications](https://www.tensorflow.org/api_docs/python/tf/keras/applications).**
#
#
# * Output: The function will create a file `Embeddings_{model_name}.csv` containing the image name and the embeddings for each image in the dataset in the directory `Embeddings`. The embeddings are represented as n columns, where n is the size of the embedding vector.

# %%
import os

batch_size = 32
path = 'data/images'
dataset = ''
backbone = 'convnextv2_tiny'
out_dir = 'Embeddings_test'

# Explicación del error:
# El error "OSError: [Errno 5] Input/output error: 'data/images'"
# ocurre típicamente cuando el sistema intenta acceder a un archivo o directorio
# pero encuentra un problema a nivel del sistema operativo, como problemas de permisos,
# un sistema de archivos corrupto o una indisponibilidad temporal de la unidad montada (Google Drive en Colab).
# El traceback indica que el error ocurrió cuando se llamó a 'os.listdir(folder_path)'
# dentro de la clase ImageFolderDataset, lo que significa que el sistema no pudo listar el contenido de 'data/images'.
#
# Para mitigar esto, especialmente en un entorno de Colab donde Google Drive puede tener problemas transitorios,
# es una buena práctica asegurarse de que el directorio exista y sea accesible antes de intentar listar su contenido.
# Una solución temporal podría implicar volver a ejecutar la celda o verificar la conexión de Google Drive.
#
# Para una solución más robusta dentro del código, podemos añadir una comprobación de la existencia del directorio
# y si contiene algún archivo. Aunque 'Errno 5' no es directamente 'No encontrado',
# asegurar que el directorio esté preparado es un buen paso.

# Añadimos una comprobación para asegurar que el directorio 'data/images' está listo.
# Nota: Esto no soluciona el problema subyacente de E/S transitorio, pero ayuda a diagnosticar si
# el directorio falta inesperadamente o está vacío.
if not os.path.exists(path):
    print(f"Error: El directorio '{path}' no existe. Por favor, asegúrate de haber descargado y colocado el contenido de 'images.zip' en '{path}' como se indica.")
    print("Se espera que este directorio esté en tu directorio de trabajo de Colab, que actualmente es:")
    print(os.getcwd())
    print("Considera volver a ejecutar los pasos de configuración de datos o verificar el montaje de tu Google Drive.")
elif not os.path.isdir(path):
    print(f"Error: '{path}' existe pero no es un directorio. Por favor, asegúrate de que sea un directorio para tus imágenes.")
elif not os.listdir(path):
    print(f"Advertencia: El directorio '{path}' está vacío. No se procesará ninguna imagen.")
    print("Por favor, asegúrate de que el contenido de 'images.zip' se haya extraído en este directorio.")
else:
    # Si el directorio existe y no está vacío, procede con la generación de embeddings.
    # Cualquier 'Errno 5' en este punto probablemente sería un problema transitorio del sistema/unidad.
    print(f"Directorio '{path}' encontrado con {len(os.listdir(path))} elementos. Continuando con la generación de embeddings...")
    get_embeddings_df(batch_size=batch_size, path=path, dataset_name=dataset, backbone=backbone, directory=out_dir)
# Out:
# Directorio 'data/images' encontrado con 49690 elementos. Continuando con la generación de embeddings...
# Skipping 3122677.jpg due to error
# Skipping 5907298.jpg due to error
# Skipping 9744871.jpg due to error
# Skipping 3459533.jpg due to error
# Skipping 9373867.jpg due to error
# Skipping 5092130.jpg due to error
# Skipping 8349075.jpg due to error
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFConvNextV2Model: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing TFConvNextV2Model from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFConvNextV2Model from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFConvNextV2Model were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFConvNextV2Model for predictions without further training.
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 61ms/step
# Batch 10/1553 done
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 20/1553 done
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 30/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# Batch 40/1553 done
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 50/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 60/1553 done
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 70/1553 done
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 80/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 37ms/step
# Batch 90/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 100/1553 done
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 110/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 120/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 130/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 140/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 150/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 160/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 86ms/step
# Batch 170/1553 done
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 180/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 190/1553 done
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 55ms/step
# Batch 200/1553 done
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 210/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 220/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# Batch 230/1553 done
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 240/1553 done
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 250/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# Batch 260/1553 done
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 270/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 280/1553 done
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# Batch 290/1553 done
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 300/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 310/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 320/1553 done
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# Batch 330/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# Batch 340/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 58ms/step
# Batch 350/1553 done
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 360/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 370/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# Batch 380/1553 done
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 390/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 400/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# Batch 410/1553 done
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 420/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 430/1553 done
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 440/1553 done
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 450/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# Batch 460/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 470/1553 done
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 480/1553 done
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 490/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 48ms/step
# Batch 500/1553 done
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 510/1553 done
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 520/1553 done
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 65ms/step
# Batch 530/1553 done
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 540/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 550/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 59ms/step
# Batch 560/1553 done
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 570/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# Batch 580/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# Batch 590/1553 done
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 600/1553 done
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 610/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 66ms/step
# Batch 620/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 630/1553 done
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 640/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# Batch 650/1553 done
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 660/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 670/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 680/1553 done
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 690/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 700/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 58ms/step
# Batch 710/1553 done
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 720/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 730/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# Batch 740/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# Batch 750/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 760/1553 done
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# Batch 770/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 780/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# Batch 790/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 69ms/step
# Batch 800/1553 done
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 810/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 820/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 830/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 840/1553 done
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 850/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# Batch 860/1553 done
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# ...
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 1260/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# Batch 1270/1553 done
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 1280/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 1290/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# Batch 1300/1553 done
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 1310/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 1320/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 58ms/step
# Batch 1330/1553 done
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# Batch 1340/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# Batch 1350/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 52ms/step
# Batch 1360/1553 done
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 1370/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# Batch 1380/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 65ms/step
# Batch 1390/1553 done
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 1400/1553 done
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 1410/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# Batch 1420/1553 done
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# Batch 1430/1553 done
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 1440/1553 done
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# Batch 1450/1553 done
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 1460/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# Batch 1470/1553 done
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# Batch 1480/1553 done
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# Batch 1490/1553 done
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# Batch 1500/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 62ms/step
# Batch 1510/1553 done
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# Batch 1520/1553 done
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# Batch 1530/1553 done
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# Batch 1540/1553 done
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# Batch 1550/1553 done
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 5s 5s/step

# %% [markdown]
# ### 2.2. Text Embeddings
#
# For text embeddings, we will use a pre-trained model to generate embeddings for the product descriptions. The model will take a text input and output a vector of fixed size that represents the text. We will use the `HuggingFaceEmbeddings` class to extract embeddings from text using a pre-trained transformer model from the Hugging Face library.
#
# * Optional: You can use the `GPT` class to generate embeddings for the product descriptions using a model avaialble in the OpenAI API.

# %% [markdown]
# 2.2.1 HuggingFaceEmbeddings
#
# The `HuggingFaceEmbeddings` class is used to generate embeddings for text data using pre-trained transformer models from the Hugging Face library. The class takes the following parameters:
#
# - `model_name`: The name of the pre-trained transformer model to use.
# - `device`: The device to use for processing the data ('cpu', 'cuda', 'mps').
# - `path`: The path to the CSV file containing the text data.
#
# The class has the method `get_embedding_df` that generates embeddings for a given text column in a CSV file and saves the embeddings to a new CSV file. The method takes the following parameters:
#
# - `column`: The name of the text column in the CSV file.
# - `directory`: The directory to save the embeddings file.
# - `file`: The name of the embeddings file to save.
#
# ```python
# # Usage example for BERT:
# device = 'mps'
# model = HuggingFaceEmbeddings(model_name='bert-base-uncased', device=device)
#
# model.path = 'data/processed_products_with_images.csv'
# column = 'description'
# directory = 'Embeddings/'
# file = 'text_embeddings_bert.csv'
#
# model.get_embedding_df(column, directory, file)
# ```
#
# * Output: The function will create a file with the defined name `file` (e.g., `text_embeddings_bert.csv`) containing the product metadata and the embeddings for each text description in the dataset. The dataset will be stored in the directory `directory` (e.g., `Embeddings/`). The embeddings are represented as a list in a **single column** with the name `embeddings`. **Don't convert the text embeddings into multiple columns in the dataframe, leave it as a list, since the conversion will be done in the next step.**
#
# **The class should work at least for `sentence-transformers/all-MiniLM-L6-v2`, but optionally, you can implement it for other models as well.**

# %%
import sys
import os

# Ensure the root directory of the project is in sys.path
# ROOT_DIR is defined in an earlier cell (MOmDt--lXwUQ).
# This assumes 'src' is directly under ROOT_DIR.
if 'ROOT_DIR' in globals() and ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
elif os.path.exists('src') and os.getcwd() not in sys.path:
    # Fallback if ROOT_DIR is not globally defined or the user is running locally
    sys.path.insert(0, os.getcwd())

from src.nlp_models import HuggingFaceEmbeddings

# Usage example for all-MiniLM-L6-v2:
device = 'cuda' # Set to 'cuda' if you have a GPU, 'cpu' otherwise
model = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', device=device)

model.path = 'data/processed_products_with_images.csv' # This is the output of the previous step
column = 'description'
directory = 'Embeddings_test/'
file = 'text_embeddings_minilm.csv'

model.get_embedding_df(column, directory, file)
# Out:
# Using device: cuda
# Model moved to device: cuda
# Model: sentence-transformers/all-MiniLM-L6-v2

# %%
import tensorflow as tf, torch
print("TF GPU:", tf.config.list_physical_devices('GPU'))
print("torch cuda:", torch.cuda.is_available())
# Out:
# TF GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# torch cuda: True

# %%
import os
print(len(os.listdir("data/images")), "de ~49689")
# Out:
# 49690 de ~49689

# %%
# Optional: Use OpenAI's API to get the embeddings

# %% [markdown]
# ### 2.3 Merge Embeddings
#
# Once you have the embeddings, you need to merge them into a single dataset. You can use the `preprocess_data` function to merge the embeddings and preprocess the dataset for training.
#
# The function needs the following parameters:
#
# - `text_data`: The path to the CSV file containing the text embeddings.
# - `image_data`: The path to the CSV file containing the image embeddings.
# - `text_id`: The name of the column containing the text IDs.
# - `image_id`: The name of the column containing the image IDs.
# - `embeddings_col`: The name of the column containing the embeddings.
#
# ```python
# preprocess_data(text_data, image_data, text_id="image_id", image_id="ImageName", embeddings_col = 'embeddings')
# ```
#
# * Output: The function will create a dataframe with the embeddings from both the text and image data. The dataframe will contain the text and image IDs, the product category, as well as the metadata for the product, and `n` + `m` new extra columns with the embeddings, where `n` is the size of the text embeddings and `m` is the size of the image embeddings. The new embedding columns will be named `text_0`, `text_1`, ..., `text_n`, `image_0`, `image_1`, ..., `image_m`.

# %%
PATH = 'Embeddings_test/'
text = pd.read_csv(os.path.join(PATH, 'text_embeddings_minilm.csv'))
images = pd.read_csv('Embeddings_test/Embeddings_convnextv2_tiny.csv')   # <-- otra carpeta

df = preprocess_data(text, images, "image_path", "ImageName")
print("filas tras el merge:", len(df))

df.to_csv(os.path.join(PATH, 'embeddings_merge.csv'), index=False)
# Out:
# filas tras el merge: 49682

# %% [markdown]
# ## 3. Machine Learning Models Training
#
# We'll be using 2 approaches to train the model:
#
# 1. A classical machine learning model using the embeddings generated from the text and image data.
# 2. A deep learning model using the embeddings generated from the text and image data to train a neural network.
#
# In order to do a fair comparison between the two approaches, we will use the same train/test split for both models. We will use 70% of the data for training and 30% for testing.

# %% [markdown]
# ### 3.1 Dataset Preparation
#
# The first step is to prepare the dataset for training. We will use the `train_test_split` function to split function from the `sklearn` library to split the dataset into training and testing sets.
#
# Then we will define the image embedding columns and the text embedding columns to be used in the model.
#
# You can use those columns to train 3 models per approach:
# * A model using only the image embeddings.
# * A model using only the text embeddings.
# * A model using both the image and text embeddings, or multimodal model.

# %%
# Read the data:
PATH = 'Embeddings_test/'
df = pd.read_csv(os.path.join(PATH, 'embeddings_merge.csv'))

# Split the data into train and test sets and extract the features
train_df, test_df, text_columns, image_columns, label_columns = train_test_split_and_feature_extraction(df)

# %% [markdown]
# ### 3.2. Classical ML model Training
#
# After generating the embeddings, we will train a machine learning model to predict the product category based on the embeddings. We will use the `train_and_evaluate_model` (`train_classic` in this code) function to train a classic machine learning model using the embeddings.
#
# **You should at least implement the following models: `RandomForest`, and `LogisticRegression`.**

# %%
### Labels
y_train = train_df[label_columns].values.ravel()
y_test  = test_df[label_columns].values.ravel()

print(y_train.shape, y_test.shape)   # (n,) y (m,), sin el segundo eje
# Out:
# (34777,) (14905,)

# %% [markdown]
# #### 3.2.1. Train and Evaluate Text Model

# %%
# Combine text columns to form the feature set
X_train = train_df[text_columns].values
X_test = test_df[text_columns].values

# Train and evaluate models
trained_models = train_classic(X_train, X_test, y_train, y_test)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40f7d42b-5ce6-4c5b-be62-76fe6062e8dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40f7d42b-5ce6-4c5b-be62-76fe6062e8dd")) {                    Plotly.newPlot(                        "40f7d42b-5ce6-4c5b-be62-76fe6062e8dd",                        [{"hovertemplate":"Class=abcat0900000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0900000","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"abcat0900000","showlegend":true,"x":[-1.910598503267085,-1.645275538455393,-1.1798926680703852,-0.5612686647212797,-1.4803393526061188,-0.5284888394065732,-1.672047717203024,-1.0298538813488152,-1.7198674934713052,-1.871161471166863,-0.9073342044309973,-0.7014366811849433,-1.491210236064476,-2.0382639303395536,-0.46032756322494,-2.0396320616897072,-1.0058292196464302,-1.2448454538608376,-0.7711070681973822,-0.7534177979023735,-0.5162772273192453,-1.2344950824355339,-0.9870168926305809,-0.5319119179249705,-0.9903789193286234,-1.9579930340662555,-0.30453011452843276,-0.9944275703370076,-0.6567503249629105,-0.4082020619638704,0.28553905888737496,-1.630181354611201,-1.5309076276320956,-1.7264163224042979,-0.4778921535751716,-1.5512460359340021,-1.5255115025930888,-1.6749617581824936,-1.4931533546900766,-2.406034674276648,0.5758853073271109,-0.6238078597770622,-0.39419463600196586,-1.7009181555119892,-0.3449820109311869,-1.5931649083646608,-0.17060993355847565,-1.163417806497778,-0.14870648614379817,-0.9632363778143811,-1.3462717511554716,-0.29639249918133864,-1.4716023476684936,-0.9674627898156647,-1.2944589656545387,-0.9076052209269942,-0.11211940141375432,-0.0661249792082691,-0.42473501765282656,-0.16708388583005251,-1.0578375267171818,-0.7027790547777699,-0.9099412844152581,-1.727298767540028,-1.7022550487791184,-0.3647922624057481,-0.2573113582317041,-1.7892893437430548,-1.8456879451901667,-1.6768956572212175,-0.7146338370453353,-1.6161026497615667,-1.817608705666686,-1.9536809281159961,-0.7642033329715008,-0.32557557999606207,0.7778988388631829,-1.0728216761120772,-0.577633996853059,-0.7617297624506063,-1.4658643835682093,-0.9168820176369641,-0.6567336131108061,-0.8557617477590063,-1.6280515226577812,-1.2013786367568597,-0.5806445702956271,-1.5823747302177247,-1.896106933779725,-0.4402327092772817,-0.42127629279901285,-0.8793729165950361,-0.616886118856953,-0.6646786914156857,-0.6601430864849551,-1.4316651893386338,-0.1353924275015006,-1.9464352501798203,-0.33117858060192945,-1.9162822958116548,-0.9941784583778193,-1.4157075990436516,-1.563648734923581,-2.4745438758528095,-1.8791613951578705,-1.3464156208757008,-0.6424388371435958,-0.3744709430180195,-0.7566390905328342,-2.084300192982196,-1.757855550070824,-1.3097644939720745,-1.350856675374231,-1.8946638284532893,-0.651615415366545,-0.4898139332634828,-1.060799893179858,-0.0912372122407189,-0.8743149663789098,-0.5232488239696025,0.3970490554882161,-1.4298407202169452,-0.5118791586506568,-1.5370575386211494,-1.2452423015282061,-1.7407226759828223,-1.5806342360788728,-0.6912259036302653,-1.1456153071812116,-1.4469016257650134,-0.6137469288897723,-1.0737857594834845,-1.436830516854433,-1.8523006995614575,-0.9861293042054626,-0.16571225945274692,-1.052288012642115,-1.3846532993756742,-0.7630158334908832,-1.7845810346441395,0.15402412540527044,-1.8087566389809908,-1.6626848678272808,-1.0337666389234716,-1.5753177940140044,-1.142056962031452,-1.881525604389217,-1.0779888918968992,-1.9644182968631843,-1.0024268428526724,-1.8152338452411254,-1.2903755403673012,-1.0531210462981522,-1.9448036728551952,-1.6754438022204747,-1.3848564865740287,-1.6856564291442973,-0.8269024237410147,-0.17363862064748387,-1.198520 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1476/379244091.py in <cell line: 0>()
#       4
#       5 # Train and evaluate models
# ----> 6 trained_models = train_classic(X_train, X_test, y_train, y_test)
#
# /content/drive/MyDrive/Spring project 3/Assignment/src/classifiers_classic_ml.py in train_and_evaluate_model(X_train, X_test, y_train, y_test, models, test)
#     236         models = [
#     237             ("Logistic Regression", LogisticRegression()),
# --> 238             ("Random Forest", RandomForestClassifier()),
#     239         ]
#     240
#
# NameError: name 'RandomForest' is not defined

# %%
# !grep -n "RandomForest" /content/drive/MyDrive/Spring\ project\ 3/Assignment/src/classifiers_classic_ml.py
# Out:
# 13:from sklearn.ensemble import RandomForestClassifier
# 238:            ("Random Forest", RandomForestClassifier()),

# %% [markdown]
# #### 3.2.2. Train and Evaluate Image Model

# %%
# Combine image columns to form the feature set
X_train = train_df[image_columns].values
X_test = test_df[image_columns].values

# Train and evaluate models
trained_models = train_classic(X_train, X_test, y_train, y_test)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="682c0cb5-d281-49d7-b7de-979b419a3c06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("682c0cb5-d281-49d7-b7de-979b419a3c06")) {                    Plotly.newPlot(                        "682c0cb5-d281-49d7-b7de-979b419a3c06",                        [{"hovertemplate":"Class=abcat0900000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0900000","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"abcat0900000","showlegend":true,"x":[0.2842850128939,0.18358840428205336,0.5215510616200325,1.1811937030701203,0.76072492658665,1.2305989063968215,-0.7481671852150367,0.6958934235644426,1.7235979925935754,0.9744569351404387,-1.7995403305268753,1.030720137841621,0.5917067156867796,0.4781426348388243,0.08171702854811791,0.03434792191002151,0.5463604572084978,1.1702273320784768,1.0648577329837796,0.9756449315906013,-0.009659918976532698,0.585866388606903,1.7373639028036114,1.0050682630229997,0.7192069946126828,0.7907067702656859,1.6009435233159144,0.8191809314127487,0.31509468898199733,2.0828084721177547,-1.5236261363731687,1.9342212343230873,0.4525648054729174,1.0157161666977623,-0.9860039537478208,0.42160582805280405,1.6746935581628544,0.5681556940755744,0.03795333602119775,1.1195796272288558,-1.2014661337469785,-1.8132779145359639,-1.6490291599095885,1.2734424064197796,0.013606946942144323,0.03693758668068622,-0.3144537288247253,0.6021393019139666,0.07237820393971861,0.18157211692513028,0.46163001587874136,0.39856563147241925,0.2533813842291988,2.693377867604327,0.2129812048820227,1.1628692529411266,-1.639661301027736,0.7498259416213372,0.4146296322357447,1.8593722000018373,0.33242058313965644,0.1760982522769041,1.0437462827729185,1.7047315605166056,0.2774000978624533,-0.05790375879947018,0.15955591091521953,1.0737443685768968,0.754694669465055,0.43793069964939707,-0.12458751212752528,0.6241767536418922,0.38261038730808744,0.32594720851983117,-0.5639753344506859,-0.0484146559878796,-2.3235717289163653,0.23146399555270453,-0.8832005481737492,0.24946994286251775,1.2983981198921255,1.2596441947767565,0.029152080595421466,1.200848890021243,0.9647078882308793,0.2169923784340979,1.8191106089569546,0.3516560721672771,0.3972479354381882,0.2935942450562165,0.438585585065752,0.05822453617282742,0.37783711005871584,0.7756010494360883,0.25292490269120954,0.3935266935952101,-2.4019971002744653,0.1761237482556288,0.5006381789397568,0.07542187934224756,0.03303934801471007,0.007833380026446686,0.4962732635238308,0.27335685154022027,0.7025660391392229,0.15583509701173545,0.24609727183824368,0.3865141054645573,0.6518264426547495,0.6033381315064316,1.8094848631169616,0.618238223799895,0.27032856107926856,1.464331167324725,-0.2627224653985131,0.053458327622457995,1.0273219816464945,1.2217557646863404,0.4542853811854578,0.060790081255328816,-2.961236776493504,0.617064933646769,-0.23332169475796366,1.7038890714010237,0.3097608512870007,2.300495462450795,0.5933464255501651,0.18431303145725494,0.15022223796189405,0.5528239702115667,0.017268149807409046,1.4086727410048132,0.19707275286831538,0.4041884953023766,0.1733173704992706,1.524574670247696,0.4349277775620895,0.33010726997785333,0.49778831075986135,0.7989159679282404,1.5857974180256844,-0.11304910592448492,0.5512872512899197,0.30791006066188387,1.1645855347765157,-0.06333711218856714,0.8438405338344349,-0.3020204347925239,0.9488693611433756,0.18967843541400403,0.4102090959732401,1.453501647915609,0.03885829752243782,1.8689508172052132,1.7411622291322206,-0.09815346503233938,0.006818744704450853,-0.22012628584383467,-0.09793748104374095,-0.13151395553602274,0.23743068187535102,0.09038336758617463,0.03310459651965276,0.9708 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1476/3039154350.py in <cell line: 0>()
#       4
#       5 # Train and evaluate models
# ----> 6 trained_models = train_classic(X_train, X_test, y_train, y_test)
#
# /content/drive/MyDrive/Spring project 3/Assignment/src/classifiers_classic_ml.py in train_and_evaluate_model(X_train, X_test, y_train, y_test, models, test)
#     236         models = [
#     237             ("Logistic Regression", LogisticRegression()),
# --> 238             ("Random Forest", RandomForestClassifier()),
#     239         ]
#     240
#
# NameError: name 'RandomForest' is not defined

# %% [markdown]
# #### 3.2.3. Train and Evaluate Combined Model

# %%
# Combine text and image columns to form the feature set
X_train = train_df[text_columns + image_columns].values
X_test = test_df[text_columns + image_columns].values

# Train and evaluate models
trained_models = train_classic(X_train, X_test, y_train, y_test)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73159329-70c1-4335-941d-0768393ae60c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73159329-70c1-4335-941d-0768393ae60c")) {                    Plotly.newPlot(                        "73159329-70c1-4335-941d-0768393ae60c",                        [{"hovertemplate":"Class=abcat0400000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0400000","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"abcat0400000","orientation":"v","showlegend":true,"x":[-1.043760555235019,-0.26047664199090537,-2.1543002893281593,-2.3090589312889893,-2.351361658950242,0.0821506916340009,-2.1298178760501494,-0.716266180099313,-1.884774168656246,-1.406526978648818,-0.5319514076679935],"xaxis":"x","y":[2.054212061693957,-2.108751924959504,5.0334244688908125,1.0830402459649093,0.5144742136248528,-0.6481309603146079,-6.22960705330377,1.235831261833537,3.3057156052913754,5.4706003447393545,5.310213082654295],"yaxis":"y","type":"scatter"},{"hovertemplate":"Class=abcat0200000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0200000","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"abcat0200000","orientation":"v","showlegend":true,"x":[-2.9604606769568713,-2.56579373283092,-1.5906477382507194,-3.7005421451763656,-5.9681448310348,-5.329214257028874,-2.6509296583652375,-5.606868213123854],"xaxis":"x","y":[4.686903855211677,5.387153426763416,5.329493125567992,0.6146281021574436,-2.5308360507313528,3.521785155685519,6.754786743676249,-1.8858015501270686],"yaxis":"y","type":"scatter"},{"hovertemplate":"Class=abcat0700000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0700000","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"abcat0700000","orientation":"v","showlegend":true,"x":[18.26846991423609,12.503276825440759,19.834249384908052,18.87192524818664,-3.000790610682603,20.09347627685377,14.079128296715027,18.61135945646486,18.97661201986593,14.955594844830562,8.349406059678742,17.361570946044736,17.95046436076706,4.981882177734305,-0.3629565267676512,-2.263501473979773,10.145536346372342,17.565688969750216,15.818740484342685,19.043612983595395,0.7921406040285299,16.362171406796865,17.721872117016197,18.61768568544097],"xaxis":"x","y":[-0.3583783112401657,-0.6382895610371762,-0.9794235446641211,-0.9344735882486632,5.465948970872436,-4.838383415529851,-4.319966782782426,-2.6161114948868653,-2.2677345089142027,-3.8785970160792442,-8.29690583472135,-3.7817643502498304,-2.7222877428732253,-4.0585854412824744,4.220706271222664,4.4335500049834975,-4.573196696319366,-5.914847003604786,-2.818669664829238,-1.2837624341404834,2.603417133779203,-5.506757063479485,-0.5203328167792729,-1.8984134791010825],"yaxis":"y","type":"scatter"},{"hovertemplate":"Class=abcat0500000\u003cbr\u003ecol1=%{x}\u003cbr\u003ecol2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"abcat0500000","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"abcat0500000","orientation":"v","showlegend":true,"x":[16.00956449717442,-4.215462118493951,-5.751516287561966,-6.434247679896438,-7.576367428740325,-6.432596980316606,-6.931538992499073,-2.3478593957143645,-3.4663921333283163,-4.623424814977783,-0.6330804494436885,-4.176583327190558,-4.840466368039415,-4.898826689258004,-1.5180238324922022,0.2730898002710579,-2.524526817212421,-1.196631490708254,-4.986009742636122,-4.40312604093969,-1.2138882012124639,-5.27808628867436],"xaxis":"x","y":[-3.7297306267113606,-4.595363922226545,-12.97205363400001,-2.975886943736288,-3.367226020379767 ...
# ####################  Random Forest  ####################
#                     precision    recall  f1-score   support
#
#       abcat0100000       0.00      0.00      0.00        10
#       abcat0200000       0.71      0.62      0.67         8
#       abcat0207000       1.00      0.12      0.22         8
#       abcat0300000       1.00      0.33      0.50         9
#       abcat0400000       0.86      0.55      0.67        11
#       abcat0500000       0.47      0.77      0.59        22
#       abcat0700000       0.88      0.88      0.88        24
#       abcat0800000       0.65      1.00      0.79        24
#       abcat0900000       0.67      0.97      0.79        30
# pcmcat139900050002       0.00      0.00      0.00         1
# pcmcat242800050021       0.00      0.00      0.00         5
# pcmcat252700050006       0.00      0.00      0.00         1
# pcmcat312300050015       0.70      0.50      0.58        14
# pcmcat332000050000       0.00      0.00      0.00         1
#
#           accuracy                           0.67       168
#          macro avg       0.50      0.41      0.41       168
#       weighted avg       0.65      0.67      0.62       168
#
# ####################  Logistic Regression  ####################
#                     precision    recall  f1-score   support
#
#       abcat0100000       0.56      0.50      0.53        10
#       abcat0200000       0.50      0.50      0.50         8
#       abcat0207000       1.00      0.38      0.55         8
#       abcat0300000       0.60      0.67      0.63         9
#       abcat0400000       0.47      0.64      0.54        11
#       abcat0500000       0.57      0.59      0.58        22
#       abcat0700000       0.89      0.67      0.76        24
#       abcat0800000       0.60      0.88      0.71        24
#       abcat0900000       0.80      0.80      0.80        30
#           cat09000       0.00      0.00      0.00         0
# pcmcat139900050002       0.00      0.00      0.00         1
# pcmcat242800050021       1.00      0.40      0.57         5
# pcmcat252700050006       0.00      0.00      0.00         1
# pcmcat312300050015       0.57      0.57      0.57        14
# pcmcat332000050000       0.00      0.00      0.00         1
#
#           accuracy                           0.65       168
#          macro avg       0.50      0.44      0.45       168
#       weighted avg       0.67      0.65      0.64       168

# %% [markdown]
# ### 3.3 Multi-layer Perceptron
#
# *Now it's time to train our first Neural Network model. For simplicity, we are going to try using an MLP model.*
#
# *A Multi-layer Perceptron (MLP) is a simple neural network consisting of multiple layers of nodes connected by weighted edges. The input and output layers have one node per feature, and one node per target class respectively, while the intermediate layers have an arbitrary number of nodes.*
#
# In this case you'll train 3 models:
# * A model using only the image embeddings.
# * A model using only the text embeddings.
# * A model using both the image and text embeddings, or multimodal model.
#
# In order to do that, you can use the `train_mlp` function to train a neural network model using the embeddings. Is important that you create a correct setup in `src/classifiers_mlp.py` to train the model.
#
# Once you train each model, it will generate a classification report and a confusion matrix to evaluate the model's performance. It will also generate a folder `results` with the files `results/multimodal_results.csv`, `results/image_results.csv`, or `results/text_results.csv` containing the results of your model on the test set. Those files are necessary for the final evaluation, so don't remove, rename or change them.
#
# **You must achieve at least 85% accuracy and 80% F1-score for the multimodal model, an accuracy of at least 85% and an F1-score of at least 80% for the text model, and an accuracy of at least 75% and an F1-score of at least 70% for the image model.**

# %% [markdown]
# #### 3.3.1 Perpare the dataset

# %%
# Initialize LabelEncoder and fit it only on the training data
label_encoder = LabelEncoder()
label_encoder.fit(train_df[label_columns])
# Out:
# LabelEncoder()

# %% [markdown]
# #### 3.3.2. Train and Evaluate the image model

# %%
# Create the datasets and ensure the encoder is passed to both train and test sets
train_dataset = MultimodalDataset(train_df, text_cols=None, image_cols=image_columns, label_col=label_columns, encoder=label_encoder)
test_dataset = MultimodalDataset(test_df, text_cols=None, image_cols=image_columns, label_col=label_columns, encoder=label_encoder)

text_input_size = None
image_input_size = len(image_columns)
output_size = label_encoder.classes_.shape[0]

# %%
# Train the model
print("Training Image Model:")
train_mlp(train_dataset, test_dataset,
            text_input_size=text_input_size,
            image_input_size=image_input_size,
            output_size=output_size,
            num_epochs=50,
            report=True,
            lr=0.001,
            set_weights=True,
            adam=True,
            p=0.2,
            seed=42,
            patience=10)
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Training Image Model:
# Epoch 1/50
# 12/12 [==============================] - 3s 24ms/step - loss: 3.0307 - accuracy: 0.1146 - val_loss: 2.4922 - val_accuracy: 0.2062
# Epoch 2/50
# 12/12 [==============================] - 0s 10ms/step - loss: 1.6777 - accuracy: 0.4453 - val_loss: 2.0738 - val_accuracy: 0.3688
# Epoch 3/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.9391 - accuracy: 0.5964 - val_loss: 1.8506 - val_accuracy: 0.4250
# Epoch 4/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6913 - accuracy: 0.7161 - val_loss: 1.6836 - val_accuracy: 0.4625
# Epoch 5/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5013 - accuracy: 0.7839 - val_loss: 1.5975 - val_accuracy: 0.4938
# Epoch 6/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3902 - accuracy: 0.8438 - val_loss: 1.4735 - val_accuracy: 0.5188
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2997 - accuracy: 0.9062 - val_loss: 1.5073 - val_accuracy: 0.5688
# Epoch 8/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2511 - accuracy: 0.9219 - val_loss: 1.3884 - val_accuracy: 0.6125
# Epoch 9/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2121 - accuracy: 0.9323 - val_loss: 1.4375 - val_accuracy: 0.6062
# Epoch 10/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1821 - accuracy: 0.9583 - val_loss: 1.4393 - val_accuracy: 0.6187
# Epoch 11/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1315 - accuracy: 0.9740 - val_loss: 1.3919 - val_accuracy: 0.6313
# Epoch 12/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1154 - accuracy: 0.9922 - val_loss: 1.4062 - val_accuracy: 0.6500
# Epoch 13/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1153 - accuracy: 0.9896 - val_loss: 1.3495 - val_accuracy: 0.6625
# Epoch 14/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0786 - accuracy: 0.9870 - val_loss: 1.3236 - val_accuracy: 0.6562
# Epoch 15/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0830 - accuracy: 1.0000 - val_loss: 1.2951 - val_accuracy: 0.6562
# Epoch 16/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0844 - accuracy: 0.9870 - val_loss: 1.3413 - val_accuracy: 0.6625
# Epoch 17/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0695 - accuracy: 0.9974 - val_loss: 1.3580 - val_accuracy: 0.6687
# Epoch 18/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0596 - accuracy: 0.9948 - val_loss: 1.3305 - val_accuracy: 0.6687
# Epoch 19/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 1.3350 - val_accuracy: 0.6562
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0504 - accuracy: 0.9948 - val_loss: 1.3566 - val_accuracy: 0.6500
# Epoch 21/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 1.3665 - val_accuracy: 0.6562
# Epoch 22/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.3227 - val_accuracy: 0.6625
# Epoch 23/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 1.3103 - val_accuracy: 0.6625
# Epoch 24/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.3235 - val_accuracy: 0.6500
# Epoch 25/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 1.3363 - val_accuracy: 0.6562
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
#                     precision    recall  f1-score   support
#
#       abcat0100000       0.83      0.50      0.62        10
#       abcat0200000       0.56      0.62      0.59         8
#       abcat0207000       0.67      0.29      0.40         7
#       abcat0300000       0.56      0.62      0.59         8
#       abcat0400000       0.50      0.60      0.55        10
#       abcat0500000       0.60      0.43      0.50        21
#       abcat0700000       0.84      0.70      0.76        23
#       abcat0800000       0.67      0.92      0.77        24
#       abcat0900000       0.82      0.85      0.84        27
#           cat09000       0.00      0.00      0.00         0
# pcmcat128500050004       0.00      0.00      0.00         0
# pcmcat139900050002       0.00      0.00      0.00         1
# pcmcat242800050021       1.00      0.40      0.57         5
# pcmcat252700050006       0.00      0.00      0.00         1
# pcmcat312300050015       0.56      0.64      0.60        14
# pcmcat332000050000       0.00      0.00      0.00         1
#
#           accuracy                           0.65       160
#          macro avg       0.48      0.41      0.42       160
#       weighted avg       0.69      0.65      0.65       160
# (<tf_keras.src.engine.functional.Functional at 0x7eff32daf390>,
#  0.65,
#  0.42428449549676334,
#  np.float64(nan))

# %% [markdown]
# #### 3.3.3. Train and Evaluate the text model

# %%
# Create the datasets and ensure the encoder is passed to both train and test sets
train_dataset = MultimodalDataset(train_df, text_cols=text_columns, image_cols=None, label_col=label_columns, encoder=label_encoder)
test_dataset = MultimodalDataset(test_df, text_cols=text_columns, image_cols=None, label_col=label_columns, encoder=label_encoder)

text_input_size = len(text_columns)
image_input_size = None
output_size = label_encoder.classes_.shape[0]

# %%
# Train the model
print("Training Text Model:")
train_mlp(train_dataset, test_dataset,
            text_input_size=text_input_size,
            image_input_size=image_input_size,
            output_size=output_size,
            num_epochs=50,
            report=True,
            lr=0.001,
            set_weights=True,
            adam=True,
            p=0.2,
            seed=42,
            patience=10)
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Training Text Model:
# Epoch 1/50
# 12/12 [==============================] - 1s 21ms/step - loss: 3.0536 - accuracy: 0.1224 - val_loss: 2.6112 - val_accuracy: 0.2125
# Epoch 2/50
# 12/12 [==============================] - 0s 9ms/step - loss: 1.6466 - accuracy: 0.3724 - val_loss: 2.4722 - val_accuracy: 0.3812
# Epoch 3/50
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1752 - accuracy: 0.5469 - val_loss: 2.3479 - val_accuracy: 0.5000
# Epoch 4/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.8434 - accuracy: 0.6823 - val_loss: 2.2393 - val_accuracy: 0.6000
# Epoch 5/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6757 - accuracy: 0.7500 - val_loss: 2.1461 - val_accuracy: 0.6750
# Epoch 6/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5154 - accuracy: 0.8099 - val_loss: 2.0465 - val_accuracy: 0.6938
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4452 - accuracy: 0.8359 - val_loss: 1.9931 - val_accuracy: 0.6875
# Epoch 8/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3908 - accuracy: 0.8854 - val_loss: 1.8685 - val_accuracy: 0.7250
# Epoch 9/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3213 - accuracy: 0.9010 - val_loss: 1.8184 - val_accuracy: 0.7437
# Epoch 10/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2573 - accuracy: 0.9375 - val_loss: 1.7397 - val_accuracy: 0.7625
# Epoch 11/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2316 - accuracy: 0.9453 - val_loss: 1.6730 - val_accuracy: 0.7625
# Epoch 12/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1934 - accuracy: 0.9714 - val_loss: 1.6185 - val_accuracy: 0.7500
# Epoch 13/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1810 - accuracy: 0.9661 - val_loss: 1.5451 - val_accuracy: 0.7688
# Epoch 14/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1558 - accuracy: 0.9766 - val_loss: 1.4552 - val_accuracy: 0.7812
# Epoch 15/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1365 - accuracy: 0.9870 - val_loss: 1.3767 - val_accuracy: 0.7875
# Epoch 16/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1229 - accuracy: 0.9922 - val_loss: 1.3573 - val_accuracy: 0.7750
# Epoch 17/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1067 - accuracy: 0.9896 - val_loss: 1.2982 - val_accuracy: 0.7937
# Epoch 18/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0989 - accuracy: 0.9922 - val_loss: 1.2498 - val_accuracy: 0.7812
# Epoch 19/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0895 - accuracy: 0.9870 - val_loss: 1.2166 - val_accuracy: 0.7750
# Epoch 20/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0791 - accuracy: 0.9948 - val_loss: 1.1581 - val_accuracy: 0.7812
# Epoch 21/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0731 - accuracy: 0.9974 - val_loss: 1.1338 - val_accuracy: 0.7875
# Epoch 22/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0642 - accuracy: 1.0000 - val_loss: 1.0953 - val_accuracy: 0.7812
# Epoch 23/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 1.0775 - val_accuracy: 0.7937
# Epoch 24/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0619 - accuracy: 0.9922 - val_loss: 1.0628 - val_accuracy: 0.7750
# Epoch 25/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0579 - accuracy: 0.9974 - val_loss: 1.0015 - val_accuracy: 0.7812
# Epoch 26/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0556 - accuracy: 0.9974 - val_loss: 0.9972 - val_accuracy: 0.7875
# Epoch 27/50
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.7750
# Epoch 28/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.9855 - val_accuracy: 0.7750
# Epoch 29/50
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0399 - accuracy: 0.9974 - val_loss: 0.9424 - val_accuracy: 0.7812
# Epoch 30/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0376 - accuracy: 0.9974 - val_loss: 0.9698 - val_accuracy: 0.7750
# Epoch 31/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0354 - accuracy: 0.9974 - val_loss: 0.9403 - val_accuracy: 0.7750
# Epoch 32/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.9196 - val_accuracy: 0.7812
# Epoch 33/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.9058 - val_accuracy: 0.7875
# Epoch 34/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.7750
# Epoch 35/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.9143 - val_accuracy: 0.7875
# Epoch 36/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.9419 - val_accuracy: 0.7812
# Epoch 37/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0301 - accuracy: 0.9974 - val_loss: 0.8922 - val_accuracy: 0.7875
# Epoch 38/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.9022 - val_accuracy: 0.7812
# Epoch 39/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0299 - accuracy: 0.9974 - val_loss: 0.8829 - val_accuracy: 0.7625
# Epoch 40/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0280 - accuracy: 0.9974 - val_loss: 0.9245 - val_accuracy: 0.7625
# Epoch 41/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.9456 - val_accuracy: 0.7625
# Epoch 42/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.9169 - val_accuracy: 0.7688
# Epoch 43/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.9358 - val_accuracy: 0.7688
# Epoch 44/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.9418 - val_accuracy: 0.7688
# Epoch 45/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.9189 - val_accuracy: 0.7750
# Epoch 46/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0170 - accuracy: 0.9974 - val_loss: 0.9399 - val_accuracy: 0.7688
# Epoch 47/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.9252 - val_accuracy: 0.7750
# Epoch 48/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.9469 - val_accuracy: 0.7750
# Epoch 49/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.9612 - val_accuracy: 0.7688
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
#                     precision    recall  f1-score   support
#
#       abcat0100000       0.64      0.78      0.70         9
#       abcat0200000       0.56      0.83      0.67         6
#       abcat0207000       0.83      0.62      0.71         8
#       abcat0300000       0.60      0.33      0.43         9
#       abcat0400000       0.80      0.80      0.80        10
#       abcat0500000       0.83      0.75      0.79        20
#       abcat0700000       0.95      0.83      0.89        24
#       abcat0800000       0.72      1.00      0.84        23
#       abcat0900000       0.85      0.93      0.89        30
# pcmcat139900050002       0.00      0.00      0.00         1
# pcmcat242800050021       1.00      0.20      0.33         5
# pcmcat252700050006       0.00      0.00      0.00         1
# pcmcat312300050015       0.70      0.54      0.61        13
# pcmcat332000050000       1.00      1.00      1.00         1
#
#           accuracy                           0.77       160
#          macro avg       0.68      0.62      0.62       160
#       weighted avg       0.79      0.77      0.76       160
# (<tf_keras.src.engine.functional.Functional at 0x7eff32f4d450>,
#  0.76875,
#  0.6182262780987855,
#  np.float64(nan))

# %% [markdown]
# #### 3.3.4. Train and Evaluate the fusion model

# %%
# Create the datasets and ensure the encoder is passed to both train and test sets
train_dataset = MultimodalDataset(train_df, text_cols=text_columns, image_cols=image_columns, label_col=label_columns, encoder=label_encoder)
test_dataset = MultimodalDataset(test_df, text_cols=text_columns, image_cols=image_columns, label_col=label_columns, encoder=label_encoder)

text_input_size = len(text_columns)
image_input_size = len(image_columns)
output_size = label_encoder.classes_.shape[0]

# %%
# Train the model
print("Training Early Fusion Model:")
train_mlp(train_dataset, test_dataset,
            text_input_size=text_input_size,
            image_input_size=image_input_size,
            output_size=output_size,
            num_epochs=50,
            report=True,
            lr=0.001,
            set_weights=True,
            adam=True,
            p=0.2,
            seed=42,
            patience=10)
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Training Early Fusion Model:
# Epoch 1/50
# 12/12 [==============================] - 1s 23ms/step - loss: 2.9591 - accuracy: 0.1406 - val_loss: 2.3674 - val_accuracy: 0.2937
# Epoch 2/50
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2389 - accuracy: 0.5000 - val_loss: 1.9089 - val_accuracy: 0.4500
# Epoch 3/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7374 - accuracy: 0.7005 - val_loss: 1.6699 - val_accuracy: 0.5375
# Epoch 4/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4485 - accuracy: 0.8021 - val_loss: 1.5504 - val_accuracy: 0.5562
# Epoch 5/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3258 - accuracy: 0.8802 - val_loss: 1.4560 - val_accuracy: 0.6000
# Epoch 6/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2465 - accuracy: 0.9245 - val_loss: 1.3750 - val_accuracy: 0.6125
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2051 - accuracy: 0.9531 - val_loss: 1.4196 - val_accuracy: 0.5938
# Epoch 8/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1480 - accuracy: 0.9844 - val_loss: 1.3088 - val_accuracy: 0.6375
# Epoch 9/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1397 - accuracy: 0.9740 - val_loss: 1.3705 - val_accuracy: 0.6125
# Epoch 10/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0967 - accuracy: 0.9870 - val_loss: 1.3618 - val_accuracy: 0.6062
# Epoch 11/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0937 - accuracy: 0.9870 - val_loss: 1.3241 - val_accuracy: 0.6313
# Epoch 12/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.9922 - val_loss: 1.3411 - val_accuracy: 0.6313
# Epoch 13/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 1.2936 - val_accuracy: 0.6438
# Epoch 14/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0676 - accuracy: 0.9974 - val_loss: 1.2906 - val_accuracy: 0.6375
# Epoch 15/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 1.2470 - val_accuracy: 0.6500
# Epoch 16/50
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0541 - accuracy: 0.9948 - val_loss: 1.3019 - val_accuracy: 0.6500
# Epoch 17/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0483 - accuracy: 0.9948 - val_loss: 1.2496 - val_accuracy: 0.6625
# Epoch 18/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 1.2860 - val_accuracy: 0.6375
# Epoch 19/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0361 - accuracy: 0.9974 - val_loss: 1.2831 - val_accuracy: 0.6438
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 1.2922 - val_accuracy: 0.6562
# Epoch 21/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0268 - accuracy: 0.9974 - val_loss: 1.3009 - val_accuracy: 0.6625
# Epoch 22/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.2626 - val_accuracy: 0.6562
# Epoch 23/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.6625
# Epoch 24/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.2880 - val_accuracy: 0.6438
# Epoch 25/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 1.2991 - val_accuracy: 0.6438
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
#                     precision    recall  f1-score   support
#
#       abcat0100000       0.67      0.40      0.50        10
#       abcat0200000       0.71      0.62      0.67         8
#       abcat0207000       0.60      0.43      0.50         7
#       abcat0300000       0.56      0.62      0.59         8
#       abcat0400000       0.70      0.70      0.70        10
#       abcat0500000       0.56      0.48      0.51        21
#       abcat0700000       0.84      0.70      0.76        23
#       abcat0800000       0.57      0.83      0.68        24
#       abcat0900000       0.81      0.81      0.81        27
#           cat09000       0.00      0.00      0.00         0
# pcmcat128500050004       0.00      0.00      0.00         0
# pcmcat139900050002       0.00      0.00      0.00         1
# pcmcat242800050021       0.67      0.40      0.50         5
# pcmcat252700050006       0.00      0.00      0.00         1
# pcmcat312300050015       0.57      0.57      0.57        14
# pcmcat332000050000       0.00      0.00      0.00         1
#
#           accuracy                           0.64       160
#          macro avg       0.45      0.41      0.42       160
#       weighted avg       0.66      0.64      0.64       160
# (<tf_keras.src.engine.functional.Functional at 0x7f008880d590>,
#  0.6375,
#  0.4246147952154931,
#  np.float64(nan))

# %% [markdown]
# Take into account that the model trained will be evaluated in multiple classes. It's important to use the right loss function and metrics for this task.
#
# Check the perfermance of the model in each class. Is the model overfitting? Underfitting? What can you do to improve the model?
#
# Aditionally, the fusion model is performing better than the individual models? Why?

# %% [markdown]
# ## 7. Optional. Make your own model
#
# The models we've trained before are just a limited set over the universe of stuff you can use.
#
# You still have a lot of things to experiment with to increase accuracy, some ideas are:
#
# 1. Use other pre-trained models for text and image embeddings.
# 2. Use closed-source models like OpenAI's models from the API.
# 2. Try adding data augmentation or any other regularization algorithms.
# 4. Check [KerasTuner](https://keras.io/api/keras_tuner/) documentation about how to efficiently test a lot of different architectures and parameters.
# 5. Is there a trade-off between the different models in terms of performance and computational cost? How would you decide which model to use in a production environment?
